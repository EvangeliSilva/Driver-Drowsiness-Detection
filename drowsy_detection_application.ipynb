# %% [markdown]
# # Webcam Application

# %%
# !pip install -U PyObjC
# !pip install playsound
# Out:
# Requirement already satisfied: PyObjC in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (9.1.1)
# Requirement already satisfied: pyobjc-core==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-AddressBook==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-AppleScriptKit==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-ApplicationServices==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-Automator==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-CFNetwork==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-Cocoa==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-CoreAudio==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-CoreAudioKit==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-CoreData==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-CoreMIDI==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-CoreServices==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-CoreText==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-DiscRecording==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-DiscRecordingUI==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-DiskArbitration==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-DVDPlayback==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-ExceptionHandling==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-InstallerPlugins==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-IOBluetooth==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-IOBluetoothUI==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-LatentSemanticMapping==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-LaunchServices==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-OSAKit==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-PreferencePanes==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-Quartz==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-ScreenSaver==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-Security==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-SecurityFoundation==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-SecurityInterface==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-SearchKit==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-SyncServices==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-SystemConfiguration==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-WebKit==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-AppleScriptObjC==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-CoreLocation==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-CoreWLAN==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-ImageCaptureCore==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-IOSurface==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-NetFS==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-OpenDirectory==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-ServiceManagement==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-iTunesLibrary==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-AVFoundation==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-CoreMedia==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-CoreMediaIO==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-IMServicePlugIn==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-StoreKit==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-SceneKit==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-libdispatch==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-libxpc==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-AudioVideoBridging==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-Accounts==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-EventKit==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-GameCenter==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-Social==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-GameKit==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-VideoToolbox==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-AVKit==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-GameController==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-MapKit==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-MediaAccessibility==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-MediaLibrary==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-MediaToolbox==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-SpriteKit==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-CloudKit==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-CoreBluetooth==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-CryptoTokenKit==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-FinderSync==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-LocalAuthentication==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-MultipeerConnectivity==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-NotificationCenter==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-Contacts==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-ContactsUI==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-Metal==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-MetalKit==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-ModelIO==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-NetworkExtension==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-Photos==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-PhotosUI==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-SafariServices==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-GameplayKit==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-Intents==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-MediaPlayer==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-ColorSync==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-CoreML==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-CoreSpotlight==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-ExternalAccessory==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShaders==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-Vision==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-AdSupport==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-BusinessChat==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-NaturalLanguage==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-Network==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-UserNotifications==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-VideoSubscriberAccount==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-AuthenticationServices==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-AutomaticAssessmentConfiguration==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-CoreHaptics==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-CoreMotion==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-DeviceCheck==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-ExecutionPolicy==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-FileProvider==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-FileProviderUI==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-LinkPresentation==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-OSLog==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-PencilKit==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-PushKit==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-QuickLookThumbnailing==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-Speech==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-SoundAnalysis==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-SystemExtensions==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-Accessibility==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-AdServices==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-AppTrackingTransparency==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-CallKit==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-ClassKit==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-KernelManagement==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShadersGraph==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-MLCompute==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-PassKit==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-ReplayKit==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-ScreenTime==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-UniformTypeIdentifiers==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-UserNotificationsUI==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-Virtualization==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-DataDetection==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-IntentsUI==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-LocalAuthenticationEmbeddedUI==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-MailKit==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-MetricKit==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-PHASE==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-ShazamKit==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-ScreenCaptureKit==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-AVRouting==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-BackgroundAssets==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-ExtensionKit==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-HealthKit==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-MetalFX==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-SafetyKit==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-SharedWithYouCore==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-SharedWithYou==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-ThreadNetwork==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-CalendarStore==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-Collaboration==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-DictionaryServices==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-FSEvents==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-InputMethodKit==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-InstantMessage==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: pyobjc-framework-ScriptingBridge==9.1.1 in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (from PyObjC) (9.1.1)
# Requirement already satisfied: playsound in /Users/evangelisilva/venv-metal/lib/python3.10/site-packages (1.3.0)

# %%
import cv2 
import numpy as np 
from playsound import playsound 
from PIL import Image, ImageDraw
import face_recognition 
from tensorflow import keras

# %% [markdown]
# ### Loading the Classifier Model

# %%
eye_model = keras.models.load_model('models/drowsiness-detection-cnn-model.h5')
# Out:
# Metal device set to: Apple M1

# %% [markdown]
# ### Capture the Eye

# %%
def eye_cropper(frame):
    """
    Detects the eye area in a given frame, crops it, 
    and resizes it to a fixed size for prediction.

    Args:
        frame: a NumPy array representing a color image

    Returns:
        A NumPy array of shape (1, 80, 80, 3) representing 
        the cropped and resized eye area for prediction. 
        Returns None if no eye is found in the given frame.
    """

    # capture facial landmarks
    facial_features_list = face_recognition.face_landmarks(frame)


    # capture eye cordinates
    try:
        eye = facial_features_list[0]['left_eye']
    except:
        try:
            eye = facial_features_list[0]['right_eye']
        except:
            return

    # establish the max x and y coordinates of the eye
    x_max = max([coordinate[0] for coordinate in eye])
    x_min = min([coordinate[0] for coordinate in eye])
    y_max = max([coordinate[1] for coordinate in eye])
    y_min = min([coordinate[1] for coordinate in eye])

    x_range = x_max - x_min
    y_range = y_max - y_min

    # add 50% cushion
    if x_range > y_range:
        right = round(.5*x_range) + x_max
        left = x_min - round(.5*x_range)
        bottom = round((((right-left) - y_range))/2) + y_max
        top = y_min - round((((right-left) - y_range))/2)
    else:
        bottom = round(.5*y_range) + y_max
        top = y_min - round(.5*y_range)
        right = round((((bottom-top) - x_range))/2) + x_max
        left = x_min - round((((bottom-top) - x_range))/2)


    # crop the image according to the coordinates determined above
    cropped = frame[top:(bottom + 1), left:(right + 1)]

    # resize the image
    cropped = cv2.resize(cropped, (80,80))
    image_for_prediction = cropped.reshape(-1, 80, 80, 3)

    return image_for_prediction

# %% [markdown]
# The following function takes an image frame and marks the facial landmarks on the image.

# %%
def mark_facial_landmarks(frame):
    """"
    The function mark_facial_landmarks takes in an image frame and marks 
    the facial landmarks on the image with green circles.

    Args:
        frame: A numpy array representing an image.
    """
    face_landmarks_list = face_recognition.face_landmarks(frame)
    for face_landmarks in face_landmarks_list:
        # Trace out each facial feature in the image with a line
        for facial_feature in face_landmarks.keys():
            if facial_feature == 'left_eye' or facial_feature == 'right_eye':
                for cord in face_landmarks[facial_feature]:
                    cv2.circle(frame, cord, radius=1, color=(0,255,0), thickness=2)

# %% [markdown]
# The following function shows the state if the eye on the given frame

# %%
def show_eye_state(image, text):
    """
    Shows the state of the eye on the input image with a text annotation.

    Args:
        image: numpy.ndarray. The input image to annotate.
        text: str. The text to annotate the image with.
    """

    # split text string into separate lines
    lines = text.split("\n")

    # define starting position of text
    pos = (50, 50)

    # loop over each line of text and draw on image
    for line in lines:
        cv2.putText(image, line, pos, cv2.FONT_HERSHEY_SIMPLEX, 0.75, (0,255,0), 1)
        pos = (pos[0], pos[1]+25)

# %% [markdown]
# The following function modifies the input image directly by adding bounding boxes around the faces.

# %%
def draw_bounding_box(image):
    """
    Takes an image as input and draws a green bounding box 
    around each face in the image. It uses the face_recognition 
    library to locate the faces in the image. 
    The function modifies the input image directly.

    Args:
        image: A numpy array representing an image in BGR format.
    """
    
    # Find the face locations in the image
    face_locations = face_recognition.face_locations(image)

    # Draw a rectangle around each face
    for (top, right, bottom, left) in face_locations:
        cv2.rectangle(image, (left, top), (right, bottom), (0,255,0), 1)

# %%
# initiate webcam
cap = cv2.VideoCapture(0)
w = cap.get(cv2.CAP_PROP_FRAME_WIDTH)
h = cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
fps = cap.get(cv2.CAP_PROP_FPS)

if not cap.isOpened():
    raise IOError('Cannot open webcam')

# %%
counter = 0

# create a while loop that runs while webcam is in use
while True:

    # capture frames being outputted by webcam
    ret, frame = cap.read()

    # use only every other frame to manage speed and memory usage
    frame_count = 0
    if frame_count == 0:
        frame_count += 1
        pass
    else:
        count = 0
        continue

    # capture and crop the eye for prediction
    image_for_prediction = eye_cropper(frame)
    try:
        image_for_prediction = image_for_prediction/255.0
    except:
        continue

    # get prediction from model
    prediction = eye_model.predict(image_for_prediction)

    # display information on the frame based on the prediction
    if prediction < 0.5:
        counter = 0
        status = 'Open'
        
        # mark eye cordinated on the frame
        mark_facial_landmarks(frame)
        
        # draw the bounding box on the frame
        draw_bounding_box(frame)
        
        # display information related to eye state on the frame
        message = 'Frames per second: '+ str(fps) + '\nEye State: ' + status + '\nDrowsiness: ' + str(round(prediction[0][0], 4))
        show_eye_state(frame, message)
        
    else:
        counter = counter + 1
        status = 'Closed'
        
        # mark eye cordinated on the frame
        mark_facial_landmarks(frame)
        
        # draw the bounding box on the frame
        draw_bounding_box(frame)
        
        # display information related to eye state on the frame
        message = 'Frames per second: '+ str(fps) + '\nEye State: ' + status + '\nEye Closure Time: ' + str(counter) + ' sec' + '\nDrowsiness: ' + str(round(prediction[0][0], 4))
        show_eye_state(frame, message)

        # alert the user if the counter exceeds 2 seconds
        if counter > 2:
            pos = (50, 175)
            cv2.putText(frame, 'Drowsiness Alert!', pos, cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255), 2)
            
            cv2.imshow('Drowsiness Detection', frame)
            k = cv2.waitKey(1)
            
            playsound('rooster.mov')
            continue
            
    cv2.imshow('Drowsiness Detection', frame)
    k = cv2.waitKey(1)
    if k == 27:
        break
        
cap.release()
cv2.destroyAllWindows()
# Out:
# 2023-05-12 09:46:20.409846: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 1/1 [==============================] - 1s 879ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 19
#      16     continue
#      18 # capture and crop the eye for prediction
# ---> 19 image_for_prediction = eye_cropper(frame)
#      20 try:
#      21     image_for_prediction = image_for_prediction/255.0
#
# Cell In[6], line 16, in eye_cropper(frame)
#       2 """
#       3 Detects the eye area in a given frame, crops it,
#       4 and resizes it to a fixed size for prediction.
#    (...)
#      12     Returns None if no eye is found in the given frame.
#      13 """
#      15 # capture facial landmarks
# ---> 16 facial_features_list = face_recognition.face_landmarks(frame)
#      19 # capture eye cordinates
#      20 try:
#
# File ~/venv-metal/lib/python3.10/site-packages/face_recognition/api.py:177, in face_landmarks(face_image, face_locations, model)
#     168 def face_landmarks(face_image, face_locations=None, model="large"):
#     169     """
#     170     Given an image, returns a dict of face feature locations (eyes, nose, etc) for each face in the image
#     171
#    (...)
#     175     :return: A list of dicts of face feature locations (eyes, nose, etc)
#     176     """
# --> 177     landmarks = _raw_face_landmarks(face_image, face_locations, model)
#     178     landmarks_as_tuples = [[(p.x, p.y) for p in landmark.parts()] for landmark in landmarks]
#     180     # For a definition of each point index, see https://cdn-images-1.medium.com/max/1600/1*AbEg31EgkbXSQehuNJBlWg.png
#
# File ~/venv-metal/lib/python3.10/site-packages/face_recognition/api.py:156, in _raw_face_landmarks(face_image, face_locations, model)
#     154 def _raw_face_landmarks(face_image, face_locations=None, model="large"):
#     155     if face_locations is None:
# --> 156         face_locations = _raw_face_locations(face_image)
#     157     else:
#     158         face_locations = [_css_to_rect(face_location) for face_location in face_locations]
#
# File ~/venv-metal/lib/python3.10/site-packages/face_recognition/api.py:105, in _raw_face_locations(img, number_of_times_to_upsample, model)
#     103     return cnn_face_detector(img, number_of_times_to_upsample)
#     104 else:
# --> 105     return face_detector(img, number_of_times_to_upsample)
#
# KeyboardInterrupt:
